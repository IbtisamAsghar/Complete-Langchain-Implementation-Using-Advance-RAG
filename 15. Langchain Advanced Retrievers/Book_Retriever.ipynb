# %% [markdown]
# # Merger Retriever and LongContextReorder | Lost in Middle Phenomenon

# %%
# Install the Require Libraries
# !pip install -qU langchain openai huggingface_hub sentence-transformers pypdf openai tiktoken langchain-community langchain-core
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 77.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['OPENAI_API_KEY'] = "sk-proj-zsA"

# %%
from langchain.document_loaders import PyPDFLoader

# %%
loader_harrypotter = PyPDFLoader('/content/Harry_Potter_Book.pdf')

# %%
document_harrypotter = loader_harrypotter.load()

# %%
loader_got = PyPDFLoader('/content/GOT.pdf')

# %%
document_got = loader_got.load()

# %%
len(document_harrypotter)
# Out:
# 7

# %%
len(document_got)
# Out:
# 11

# %% [markdown]
# # Now Performing the chunking

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 600,
    chunk_overlap = 150
)

# %%
text_harrypotter = text_splitter.split_documents(document_harrypotter)

# %%
text_got = text_splitter.split_documents(document_got)

# %%
print(len(text_harrypotter))
print(len(text_got))
# Out:
# 91
# 145

# %% [markdown]
# # Load the Embedding Model to convert the Data into Vector

# %%
from langchain.embeddings import HuggingFaceEmbeddings , OpenAIEmbeddings , HuggingFaceBgeEmbeddings

# %%
hf_embeddings = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
# Out:
# /tmp/ipython-input-1011331094.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   hf_embeddings = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
hf_bge_embeddings = HuggingFaceBgeEmbeddings(model_name = 'BAAI/bge-large-en')
# Out:
# /tmp/ipython-input-2664536701.py:1: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   hf_bge_embeddings = HuggingFaceBgeEmbeddings(model_name = 'BAAI/bge-large-en')
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# ...

# %%
openai_embeddings = OpenAIEmbeddings()
# Out:
# /tmp/ipython-input-868021088.py:1: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   openai_embeddings = OpenAIEmbeddings()

# %% [markdown]
# # Now Ingest the Data into the Chroma Database

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 94.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 73.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 101.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 10.9 MB/s eta 0:00:00
# ...

# %%
# from langchain.vectorstores import chromadb # Removed this line
from langchain.vectorstores import Chroma
import chromadb

# %%
# Now i am checking the current directory beacuse i am not using the cloud version of the chroma, i will store the data inside my local storage
os.getcwd()
# Out:
# '/content'

# %%
# Creating the root directory
Current_directory = os.path.dirname(os.path.abspath(".")) # this is representing to the root directory
print(Current_directory)
# Out:
# /

# %%
VDB_Directory = os.path.join(Current_directory , "/content/VDB")

# %%
VDB_Directory
# Out:
# '/content/VDB'

# %%
cleint_setting_chroma = chromadb.config.Settings(
    is_persistent = True, # Make the database permanent and save data to disk
    persist_directory = VDB_Directory, # where to save the vector database files.
    anonymized_telemetry = False # it sends usage stats (like how you use Chroma) back to the developers.
)

# %% [markdown]
# # Creating the two separte collection in one database

# %%
harrypotter_vectorstore = Chroma.from_documents(
  documents = text_harrypotter,
  embedding=hf_embeddings,
  client_settings= cleint_setting_chroma,
  collection_name = "Harrypotter",
  collection_metadata={"hnsw":"cosine"}, # base on cosine similarity i will fecth the data
  persist_directory = "/store/harrypotter"
)

# %%
got_vectorstore = Chroma.from_documents(
    documents = text_got,
    embedding=hf_embeddings,
    client_settings = cleint_setting_chroma,
    collection_name = "Gamesofthrones",
    collection_metadata={"hnsw":"cosine"},
    persist_directory = "/store/got"
)

# %% [markdown]
# # Now creating a Retriever

# %%
retriever_harrypotter = harrypotter_vectorstore.as_retriever(
    search_type = "mmr",
    search_kwargs = {"k":5 , "include_metadata":True}
)

# %%
retriever_got = got_vectorstore.as_retriever(
    search_type = "mmr",
    search_kwargs = {"k":5 , "include_metadata":True}
)

# %% [markdown]
# # Solution (Merge Both Retriever)
#
# ## Lord of Retrievers (LOTR)

# %%
from langchain.retrievers.merger_retriever import MergerRetriever

# %%
lotr = MergerRetriever(retrievers=[retriever_harrypotter , retriever_got])

# %%
query = 'why coldemort needed Harry potter help?'

results = lotr.invoke(query)

# %%
len(results)
# Out:
# 10

# %%
results[1].page_content
# Out:
# 'cold\n \n.\n \n.\n \n.\n \n”\n \nWill\n \nbegan.\n \n“Have\n \nyou\n \ndrawn\n \nany\n \nwatches\n \nthis\n \npast\n \nweek,\n \nWill?”\n \n“Yes,\n \nm’lord.”\n \nThere\n \nnever\n \nwas\n \na\n \nweek\n \nwhen\n \nhe\n \ndid\n \nnot\n \ndraw\n \na\n \ndozen\n \nbloody\n \nwatches.\n \nWhat\n \nwas\n \nthe\n \nman\n \ndriving\n \nat?\n \n“And\n \nhow\n \ndid\n \nyou\n \nfind\n \nthe\n \nWall?”\n \n“Weeping,”\n \nWill\n \nsaid,\n \nfrowning.\n \nHe\n \nsaw\n \nit\n \nclear\n \nenough,\n \nnow\n \nthat\n \nthe\n \nlordling\n \nhad\n \npointed\n \nit\n \nout.\n \n“They\n \ncouldn’t\n \nhave\n \nfroze.\n \nNot\n \nif\n \nthe\n \nWall\n \nwas\n \nweeping.\n \nIt\n \nwasn’t\n \ncold\n \nenough.”\n \nRoyce\n \nnodded.\n \n“Bright\n \nlad.\n \nWe’ve\n \nhad'

# %%
for i, doc in enumerate(results, 1):
    print(f"--- Document {i} (source: {doc.metadata.get('source')}) ---")
    print(doc.page_content[:500], "...")  # print first 500 chars
    print()
# Out:
# --- Document 1 (source: /content/Harry_Potter_Book.pdf) ---
# be observed in the characters, the different scenes as well
# as the spirit conveyed in the book.
# This paper mainly discussed different images and
# values in Harry Potter and the Philosopher’ s Stone from
# the perspective of magic realism. Apart from the general
# abstract, introduction, conclusion and reference, it first
# introduced the research objective, Harry Potter series in
# terms of the reputation they enjoy and most importantly,
# the outstanding British  novelist  and screenwriter, J. K.  ...
#
# --- Document 2 (source: /content/GOT.pdf) ---
# cold
#
# .
#
# .
#
# .
#
# ”
#
# Will
#
# began.
#
# “Have
#
# you
#
# drawn
#
# any
#
# watches
#
# this
#
# past
#
# week,
#
# Will?”
#
# “Yes,
#
# m’lord.”
#
# There
#
# never
#
# was
#
# a
#
# week
#
# when
#
# he
#
# did
#
# not
#
# draw
#
# a
#
# dozen
#
# bloody
#
# watches.
#
# What
#
# was
#
# the
#
# man
#
# driving
#
# at?
#
# “And
#
# how
#
# did
#
# you
#
# ...

# %% [markdown]
# # Filter the ouput

# %%
from langchain.document_transformers import (
    EmbeddingsClusteringFilter,
    EmbeddingsRedundantFilter, # same retrieved document will be removed
)
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import DocumentCompressorPipeline
from langchain.document_transformers import LongContextReorder

# %%
from re import search
filter = EmbeddingsRedundantFilter(embeddings=hf_embeddings)
reordering = LongContextReorder()
pipeline = DocumentCompressorPipeline(transformers=[filter, reordering])

# %%
comression_retriever = ContextualCompressionRetriever(
    base_compressor = pipeline,
    base_retriever = lotr,
    search_kwargs = {"k":3 , "include_metadata":True}
)

# %%
# !pip install langchain_openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 6.2 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import ChatOpenAI
chat_model = ChatOpenAI()

# %%
from langchain.chains import RetrievalQA

qa = RetrievalQA.from_chain_type(
    llm = chat_model,
    chain_type = "stuff",
    retriever = comression_retriever,
    return_source_documents = True,
    verbose = True
)

# %%
query = "Compare the royce with harry and tell me which is stronger"
results = qa(query)

print(results['result'])
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.
# Ser Waymar Royce and Harry Potter come from different fictional worlds and have different strengths in their respective stories.
#
# Ser Waymar Royce is a knight from the "A Song of Ice and Fire" series known for his swordsmanship and noble upbringing. He displays bravery and skill in combat, but ultimately meets his end in a confrontation with supernatural beings.
#
# Harry Potter, on the other hand, is a wizard from the "Harry Potter" series who gains strength from his ability to love, his friendships, and his skills in magic. He faces challenges that test his courage, intellect, and magical abilities.
#
# ...

# %%
# !pip install gradio

# %%
import gradio as gr
from langchain.chains import RetrievalQA
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.llms import HuggingFaceHub
from langchain_openai import ChatOpenAI
# ---- Embeddings & LLM (loaded once globally) ----
hf_embeddings = HuggingFaceBgeEmbeddings(model_name="BAAI/bge-small-en")

llm = ChatOpenAI(model='gpt-3.5-turbo')

# Global retriever (updated once after PDF upload)
retriever = None
qa_chain = None

# ---- Process PDFs (done once) ----
def process_pdfs(pdf_files):
    global retriever, qa_chain
    docs = []
    for pdf in pdf_files:
        loader = PyPDFLoader(pdf.name)
        docs.extend(loader.load())

    # Text splitting (reduced overlap = faster)
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    split_docs = text_splitter.split_documents(docs)

    # Persist embeddings only once
    vectorstore = Chroma.from_documents(split_docs, hf_embeddings, persist_directory="./db")
    retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

    # Build QA chain once
    qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever, chain_type="stuff")
    return "✅ PDFs processed successfully!"

# ---- Answer function ----
def ask_question(query):
    if qa_chain is None:
        return "⚠️ Please upload PDFs first."
    return qa_chain.run(query)

# ---- Gradio UI ----
with gr.Blocks() as demo:
    gr.Markdown("## ⚡ Fast PDF Question Answering Bot")

    with gr.Row():
        file_upload = gr.File(
            file_types=[".pdf"],
            file_count="multiple",
            label="Upload PDFs"
        )

    upload_button = gr.Button("📂 Upload & Process PDFs")
    status_output = gr.Textbox(label="Status", interactive=False)

    question = gr.Textbox(label="Ask a Question")
    answer = gr.Textbox(label="Answer", interactive=False)

    upload_button.click(process_pdfs, inputs=[file_upload], outputs=[status_output])
    question.submit(ask_question, inputs=[question], outputs=[answer])

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://8040f1d053d848d8a8.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8040f1d053d848d8a8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
